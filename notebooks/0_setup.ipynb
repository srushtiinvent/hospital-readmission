# %%
# Verify project structure
print("Project Structure Verification:")
print("-" * 50)
for directory in [DATA_DIR, MODELS_DIR, BACKEND_DIR, FRONTEND_DIR]:
    if directory.exists():
        print(f"✓ {directory.name} directory exists")
    else:
        print(f"✗ {directory.name} directory missing")

# Check for data files
print("\nData Files Verification:")
print("-" * 50)
if (DATA_DIR / 'raw_data.csv').exists():
    print("✓ raw_data.csv found")
if (DATA_DIR / 'cleaned_data.csv').exists():
    print("✓ cleaned_data.csv found")

print("\n✓ Setup complete! Ready to proceed with analysis.")

# %% [markdown]
# ## 4. Verify Installation and Setup
#
# Run verification checks to ensure everything is configured correctly.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

print("✓ Core libraries imported successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")

# %% [markdown]
# ## 3. Import Core Libraries
#
# Import essential libraries for the project.

# %%
import os
from pathlib import Path

# Set up project paths
PROJECT_ROOT = Path('../').resolve()
DATA_DIR = PROJECT_ROOT / 'data'
MODELS_DIR = PROJECT_ROOT / 'models'
BACKEND_DIR = PROJECT_ROOT / 'backend'
FRONTEND_DIR = PROJECT_ROOT / 'frontend'

# Create necessary directories if they don't exist
for directory in [DATA_DIR, MODELS_DIR]:
    directory.mkdir(exist_ok=True)

# Set environment variables
os.environ['PROJECT_ROOT'] = str(PROJECT_ROOT)
os.environ['DATA_DIR'] = str(DATA_DIR)

print(f"Project Root: {PROJECT_ROOT}")
print(f"Data Directory: {DATA_DIR}")
print(f"Models Directory: {MODELS_DIR}")
print("✓ Project environment configured!")

# %% [markdown]
# ## 2. Configure Project Environment
#
# Set up environment variables and project configuration.

# %%
import subprocess
import sys

# Core packages
packages = [
    'pandas==2.0.0',
    'numpy==1.24.0',
    'scikit-learn==1.2.0',
    'joblib==1.2.0',
    'matplotlib==3.7.0',
    'seaborn==0.12.0',
    'plotly==5.13.0'
]

print("Installing dependencies...")
for package in packages:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', package])
print("✓ All dependencies installed successfully!")

# %% [markdown]
# ## 1. Install Required Dependencies
#
# Install all necessary packages for data processing, machine learning, and visualization.

# %% [markdown]
# # Hospital Readmission Prediction - Project Setup
#
# This notebook walks through the initial setup and configuration of the hospital readmission prediction project.
